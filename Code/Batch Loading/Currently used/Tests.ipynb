# %%
import os
import h5py
import shutil
import pandas as pd
from astropy.nddata.utils import Cutout2D
from astropy.io import fits
from astropy import table
import numpy as np
import matplotlib.pyplot as plt
from astropy.visualization import (ZScaleInterval, ImageNormalize)
from astropy.visualization import make_lupton_rgb
from collections import Counter
from tensorflow import keras
from astropy.wcs import WCS,utils
import random
from functions import create_cutouts

# %%
os.path.expandvars("$SLURM_TMPDIR")

scratch = os.path.expandvars("$SCRATCH")
cat = scratch + '/catalogues'

# %%
id_done= [i[5:12] for i in os.listdir(cat)]

# %%
id_done.index('000.196')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-17be26072251> in <module>
# ----> 1 id_done.index('000.196')
#
# ValueError: '000.196' is not in list

# %%
import csv
file = open("all_files.list", "r")
csv_reader = csv.reader(file)

all_tiles = []
for row in csv_reader:
    all_tiles.append(row[0])

print(all_tiles)
# Out:
# ['CFIS.000.179.u', 'CFIS.000.180.u', 'CFIS.000.181.u', 'CFIS.000.182.u', 'CFIS.000.183.u', 'CFIS.000.184.u', 'CFIS.000.185.u', 'CFIS.000.186.u', 'CFIS.000.187.u', 'CFIS.000.188.u', 'CFIS.000.189.u', 'CFIS.000.190.u', 'CFIS.000.191.u', 'CFIS.000.192.u', 'CFIS.000.193.u', 'CFIS.000.194.u', 'CFIS.000.195.u', 'CFIS.000.196.u', 'CFIS.000.197.u', 'CFIS.000.198.u', 'CFIS.000.199.u', 'CFIS.000.200.u', 'CFIS.000.201.u', 'CFIS.000.202.u', 'CFIS.000.203.u', 'CFIS.000.204.u', 'CFIS.000.205.u', 'CFIS.000.206.u', 'CFIS.000.207.u', 'CFIS.000.208.u', 'CFIS.000.209.u', 'CFIS.000.210.u', 'CFIS.000.211.u', 'CFIS.000.212.u', 'CFIS.000.213.u', 'CFIS.000.214.u', 'CFIS.000.215.u', 'CFIS.000.216.u', 'CFIS.000.217.u', 'CFIS.000.218.u', 'CFIS.000.219.u', 'CFIS.000.220.u', 'CFIS.000.221.u', 'CFIS.000.222.u', 'CFIS.000.223.u', 'CFIS.000.224.u', 'CFIS.000.225.u', 'CFIS.000.226.u', 'CFIS.000.227.u', 'CFIS.000.228.u', 'CFIS.000.229.u', 'CFIS.000.230.u', 'CFIS.000.231.u', 'CFIS.000.232.u', 'CFIS.000.233.u', 'CFIS.000.234.u', 'CFIS.000.235.u', 'CFIS.000.236.u', 'CFIS.000.237.u', 'CFIS.000.238.r', 'CFIS.000.238.u', 'CFIS.000.239.r', 'CFIS.000.239.u', 'CFIS.000.240.r', 'CFIS.000.240.u', 'CFIS.000.241.r', 'CFIS.000.241.u', 'CFIS.000.242.r', 'CFIS.000.242.u', 'CFIS.000.243.r', 'CFIS.000.243.u', 'CFIS.000.244.r', 'CFIS.000.244.u', 'CFIS.000.245.r', 'CFIS.000.245.u', 'CFIS.000.246.r', 'CFIS.000.246.u', 'CFIS.000.247.r', 'CFIS.000.247.u', 'CFIS.000.248.r', 'CFIS.000.248.u', 'CFIS.000.249.r', 'CFIS.000.249.u', 'CFIS.000.250.r', 'CFIS.000.250.u', 'CFIS.000.251.r', 'CFIS.000.251.u', 'CFIS.000.252.r', 'CFIS.000.252.u', 'CFIS.000.253.r', 'CFIS.000.253.u', 'CFIS.000.254.r', 'CFIS.000.254.u', 'CFIS.000.255.r', 'CFIS.000.255.u', 'CFIS.000.256.u', 'CFIS.000.257.u', 'CFIS.000.258.u', 'CFIS.000.259.u', 'CFIS.000.260.u', 'CFIS.000.261.u', 'CFIS.000.262.u', 'CFIS.000.263.u', 'CFIS.000.264.u', 'CFIS.000.265.u', 'CFIS.001.179.u', 'CFIS.001.180.u', 'CFIS.001.181.u', 'CFIS.001.182.u', 'CFIS.001.183.u', 'CFIS.001.184.u', 'CFIS.001.185.u', 'CFIS.001.186.u', 'CFIS.001.187.u', 'CFIS.001.188.u', 'CFIS.001.189.u', 'CFIS.001.190.u', 'CFIS.001.191.u', 'CFIS.001.192.u', 'CFIS.001.193.u', 'CFIS.001.194.u', 'CFIS.001.195.u', 'CFIS.001.196.u', 'CFIS.001.197.u', 'CFIS.001.198.u', 'CFIS.001.199.u', 'CFIS.001.200.u', 'CFIS.001.201.u', 'CFIS.001.202.u', 'CFIS.001.203.u', 'CFIS.001.204.u', 'CFIS.001.205.u', 'CFIS.001.206.u', 'CFIS.001.207.u', 'CFIS.001.208.u', 'CFIS.001.209.u', 'CFIS.001.210.u', 'CFIS.001.211.u', 'CFIS.001.212.u', 'CFIS.001.213.u', 'CFIS.001.214.u', 'CFIS.001.215.u', 'CFIS.001.216.u', 'CFIS.001.217.u', 'CFIS.001.218.u', 'CFIS.001.219.u', 'CFIS.001.220.u', 'CFIS.001.221.u', 'CFIS.001.222.u', 'CFIS.001.223.u', 'CFIS.001.224.u', 'CFIS.001.225.u', 'CFIS.001.226.u', 'CFIS.001.227.u', 'CFIS.001.228.u', 'CFIS.001.229.u', 'CFIS.001.230.u', 'CFIS.001.231.u', 'CFIS.001.232.u', 'CFIS.001.233.u', 'CFIS.001.234.u', 'CFIS.001.235.u', 'CFIS.001.236.u', 'CFIS.001.237.u', 'CFIS.001.238.r', 'CFIS.001.238.u', 'CFIS.001.239.r', 'CFIS.001.239.u', 'CFIS.001.240.r', 'CFIS.001.240.u', 'CFIS.001.241.r', 'CFIS.001.241.u', 'CFIS.001.242.r', 'CFIS.001.242.u', 'CFIS.001.243.r', 'CFIS.001.243.u', 'CFIS.001.244.r', 'CFIS.001.244.u', 'CFIS.001.245.r', 'CFIS.001.245.u', 'CFIS.001.246.r', 'CFIS.001.246.u', 'CFIS.001.247.r', 'CFIS.001.247.u', 'CFIS.001.248.r', 'CFIS.001.248.u', 'CFIS.001.249.r', 'CFIS.001.249.u', 'CFIS.001.250.r', 'CFIS.001.250.u', 'CFIS.001.251.r', 'CFIS.001.251.u', 'CFIS.001.252.r', 'CFIS.001.252.u', 'CFIS.001.253.r', 'CFIS.001.253.u', 'CFIS.001.254.r', 'CFIS.001.254.u', 'CFIS.001.255.r', 'CFIS.001.255.u', 'CFIS.001.256.u', 'CFIS.001.257.u', 'CFIS.001.258.u', 'CFIS.001.259.u', 'CFIS.001.260.u', 'CFIS.001.261.u', 'CFIS.001.262.u', 'CFIS.001.263.u', 'CFIS.001.264.u', 'CFIS.001.265.u', 'CFIS.002.179.u', 'CFIS.002.180.u', 'CFIS.002.181.u', 'CFIS.002.182.u', 'CFIS.002.183.u', 'CFIS.002.184.u', 'CFIS.002.185.u', 'CFIS.002.186.u', 'CFIS.002.187.u', 'CFIS.002.188.u', 'CFIS.002.189.u', 'CFIS.002.190.u', 'CF ...

# %%
remaining_tiles = [x for x in all_tiles if x[5:12] not in id_done]

# %%
print(len(all_tiles),len(remaining_tiles))
# Out:
# 43031 42201

# %%
with open('remaining_tiles.list', 'w', newline='') as myfile:
    wr = csv.writer(myfile,delimiter=' ')
    wr.writerow(remaining_tiles)

# %%
file_name = "confirmed_cfis_64p.h5"

# %%
#useful directories
os.path.expandvars("$SLURM_TMPDIR")

src = os.path.expandvars("$SCRATCH") + file_name
dest = os.path.expandvars("$SLURM_TMPDIR") + "/"

image_dir = "/home/anahoban/projects/rrg-kyi/astro/cfis/W3/"
label_dir = "labels/"

# %%
hf = h5py.File(os.path.expandvars("$SCRATCH/")+file_name, "r")
#hf.close()


#shutil.copy2(src, dest)

# %%
hf.close()

# %%
pd.read_csv(os.path.expandvars("$SCRATCH") + '/master_catalogue.csv')
# Out:
#         Unnamed: 0  NUMBER    X_IMAGE    Y_IMAGE  ALPHA_J2000  DELTA_J2000  \
# 0                0     NaN        NaN        NaN          NaN          NaN
# 1              101   102.0  8682.0068   175.7034     1.810001    -0.248942
# 2             1010  1011.0  6773.0195  1870.0000     1.908508    -0.161515
# 3             1016  1017.0  4769.4888  1877.5187     2.011895    -0.161127
# 4             1070  1071.0  4596.8198  1938.1915     2.020805    -0.157996
# ...            ...     ...        ...        ...          ...          ...
# 103596        9724  9725.0  7504.3320  9606.3154   356.870771     0.237695
# 103597        9735  9736.0   924.3973  9668.8232   357.210310     0.240919
# 103598        9756  9757.0  1998.9895  9392.6816   357.154859     0.226671
# 103599        9763  9764.0  2003.9287  9628.6689   357.154604     0.238848
# 103600         991   992.0  1515.3402   362.1028   357.179816    -0.239324
#
#         MAG_AUTO  MAGERR_AUTO  MAG_BEST  MAGERR_BEST  ...  ERRB_WORLD  \
# 0            NaN          NaN       NaN          NaN  ...         NaN
# 1        24.6370       0.3051   24.6370       0.3051  ...    0.000011
# 2        24.0965       0.2219   24.0965       0.2219  ...    0.000006
# 3        24.9089       0.4511   24.9089       0.4511  ...    0.000009
# 4        24.3398       0.3159   24.3398       0.3159  ...    0.000009
# ...          ...          ...       ...          ...  ...         ...
# 103596   25.1215       0.2725   25.1215       0.2725  ...    0.000012
# 103597   25.0175       0.4834   25.0175       0.4834  ...    0.000016
# 103598   24.6522       0.2776   24.6522       0.2776  ...    0.000011
# 103599   24.8426       0.3540   24.8426       0.3540  ...    0.000015
# 103600   23.9632       0.5432   23.9632       0.5432  ...    0.000009
#
#         THETA_J2000  ERRTHETA_J2000  ISOAREA_IMAGE   MU_MAX  FLUX_RADIUS  \
# 0               NaN             NaN            NaN      NaN          NaN
# 1             85.15           89.75            6.0  23.5522        1.619
# 2            -90.00          -90.00            2.0  23.6126        2.422
# 3            -46.02           18.80            3.0  23.5518        1.410
# 4             43.82           44.91            5.0  22.9621        1.732
# ...             ...             ...            ...      ...          ...
# 103596        45.82           44.98            1.0  23.5814        1.757
# 103597        81.07           82.30           11.0  24.0934        1.863
# 103598       -12.98          -13.23            8.0  24.0695        2.592
# 103599        10.83           10.65           10.0  24.1534        2.171
# 103600        56.72           57.35           24.0  23.8102        2.360
#
#         FLAGS    TILE  BAND  CUTOUT
# 0         NaN     NaN   NaN     NaN
# 1         0.0    4.18     u    c101
# 2         0.0    4.18     u   c1010
# 3         0.0    4.18     u   c1016
# 4         0.0    4.18     u   c1070
# ...       ...     ...   ...     ...
# 103596    0.0  714.18     u   c9724
# 103597    0.0  714.18     u   c9735
# 103598    0.0  714.18     u   c9756
# 103599    0.0  714.18     u   c9763
# 103600    0.0  714.18     u    c991
#
# [103601 rows x 25 columns]

# %%
tile =  '163.275.u'
cat_r = table.Table.read(image_dir + 'CFIS.' + tile + '.cat', format="ascii.sextractor")
keys = list(cat_r.keys())

# %%
data0
# Out:
# <Row index=0>
# NUMBER  X_IMAGE  Y_IMAGE ALPHA_J2000 DELTA_J2000 MAG_AUTO MAGERR_AUTO MAG_BEST MAGERR_BEST MAG_APER MAGERR_APER   A_WORLD     ERRA_WORLD    B_WORLD     ERRB_WORLD  THETA_J2000 ERRTHETA_J2000 ISOAREA_IMAGE     MU_MAX    FLUX_RADIUS FLAGS
#           pix      pix       deg         deg       mag        mag       mag        mag       mag        mag         deg          deg          deg          deg          deg          deg            pix2     mag / arcsec2     pix
# int64   float64  float64   float64     float64   float64    float64   float64    float64   float64    float64     float64      float64      float64      float64      float64      float64         int64        float64      float64   int64
# ------ --------- ------- ----------- ----------- -------- ----------- -------- ----------- -------- ----------- ------------ ------------ ------------ ------------ ----------- -------------- ------------- ------------- ----------- -----
#      1 9228.7871  91.631 120.3138141  47.2462688  21.2819      0.0369  21.2819      0.0369  21.5467      0.0271 0.0004133937 1.184383e-05 0.0001700678 4.608522e-06      -71.46         -71.14           382       23.0275       8.228     0

# %%
data0 = cat_r[0]

# %%
new_cutout = pd.DataFrame(index = [1], data=np.array(data0), columns = keys + ['TILE'] + ['BAND'] + ['CUTOUT'])

# %%
np.array(hf[tile[:-2]+'/IMAGES/c0']).shape
# Out:
# (64, 64, 5)

# %%
a = [10,20,10]
b = [1,2,3]
10 in a and 10 not in b
# Out:
# True

# %%
cat_r[600][]
# Out:
# <Row index=600>
# NUMBER  X_IMAGE   Y_IMAGE  ALPHA_J2000 DELTA_J2000 MAG_AUTO MAGERR_AUTO MAG_BEST MAGERR_BEST MAG_APER MAGERR_APER   A_WORLD     ERRA_WORLD    B_WORLD     ERRB_WORLD  THETA_J2000 ERRTHETA_J2000 ISOAREA_IMAGE     MU_MAX    FLUX_RADIUS FLAGS
#           pix       pix        deg         deg       mag        mag       mag        mag       mag        mag         deg          deg          deg          deg          deg          deg            pix2     mag / arcsec2     pix
# int64   float64   float64    float64     float64   float64    float64   float64    float64   float64    float64     float64      float64      float64      float64      float64      float64         int64        float64      float64   int64
# ------ --------- --------- ----------- ----------- -------- ----------- -------- ----------- -------- ----------- ------------ ------------ ------------ ------------ ----------- -------------- ------------- ------------- ----------- -----
#    601 8925.7246 1193.1638   1.7974242  -0.1964397  24.6599      0.5233  24.6599      0.5233  25.3267       2.186 7.917221e-05 2.004378e-05 2.926118e-05 7.438621e-06       -9.17          -9.15             7        23.808       1.876     0

# %%
img_group_name = '197.271/IMAGES'
j=0
filters = ["CFIS u/", "PS1 g/", "CFIS r/", "PS1 i/", "PS1 z/"]
filter_dict = {k:v for v,k in enumerate(filters)}
f = 'CFIS u/'
hf[img_group_name + f"/c{j}-r"][...,filter_dict[f]].shape
# Out:
# (64, 64)

# %%
hf = h5py.File( src, "r")

# %%
for i in range(5):
    plt.imshow(np.array(hf.get('004.180/IMAGES/c100'))[...,i])
    plt.show()

# %%
hf.close()

# %%
tile_file = open(image_dir + "tiles_cand.list", "r")
tile_list = tile_file.readlines()
for i in range(len(tile_list)):
    tile_list[i] = tile_list[i][:-1] # Remove new line characters
    #print(tile_list[i])
tile_file.close()

# %%
label_subdirs = ["stronglensdb_confirmed_unige/", "stronglensdb_candidates_unige/", "canameras2020/",
                 "huang2020a_grade_A/", "huang2020a_grade_B/", "huang2020a_grade_C/", 
                 "huang2020b_grade_A/", "huang2020b_grade_B/", "huang2020b_grade_C/"]
filters = ["CFIS u/", "PS1 g/", "CFIS r/", "PS1 i/", "PS1 z/"]
filter_dict = {k:v for v,k in enumerate(filters)}

# %%
len_cat = []
count =0 
for label_subdir in [label_subdirs[0]]:
    for f in [filters[2]]:
        subdir = label_dir + label_subdir + f
        for csv in os.listdir(subdir):
            if csv != ".ipynb_checkpoints":
                #tile_id = csv[:7] 
                count += 1
                #tile_name = f.split(" ")[0] + "." + tile_id + "." + f.split(" ")[1][0]
                
                #cat = table.Table.read(image_dir+ tile_name + '.cat', format="ascii.sextractor")
                #len_cat.append(len(cat))

# %%
400*259
# Out:
# 103600

# %%
min(len_cat)
# Out:
# 430

# %%
#number of cutouts per tile for u and r tiles
plt.hist(len_cat, bins = 100);

# %% [markdown]
# right now, taking u confirmed cutouts (and saves coordinates for tile in r later) + new 300 cutouts
# then for r list, taking new cutout (confirmed in r) + u confirmed in r + 300 same cutouts from u in r

# %%
csv
# Out:
# '452.239_labels.csv'

# %%
for i in list(hf.keys()):
    del hf[i]
hf.keys()
# Out:
# <KeysViewHDF5 []>

# %%
#clean directory
for label_subdir in [label_subdirs[0]]:
    for f in [filters[2],filters[0]]:
        subdir = label_dir + label_subdir + f
        print(subdir)
        z = 1
        for csv in os.listdir(subdir):
            if csv == '.ipynb_checkpoints':
                del csv
            else:
                print(csv)
# Out:
# labels/stronglensdb_confirmed_unige/CFIS r/
# 197.271_labels.csv
# 248.272_labels.csv
# 203.263_labels.csv
# 165.270_labels.csv
# 201.311_labels.csv
# 241.290_labels.csv
# 204.278_labels.csv
# 147.288_labels.csv
# 260.284_labels.csv
# 234.295_labels.csv
# 206.264_labels.csv
# 254.287_labels.csv
# 246.289_labels.csv
# 228.262_labels.csv
# 070.320_labels.csv
# 340.274_labels.csv
# 246.291_labels.csv
# 403.238_labels.csv
# 269.283_labels.csv
# 238.293_labels.csv
# 230.296_labels.csv
# 188.307_labels.csv
# 164.282_labels.csv
# 264.299_labels.csv
# 236.293_labels.csv
# 442.244_labels.csv
# 211.252_labels.csv
# 407.242_labels.csv
# 162.275_labels.csv
# 238.291_labels.csv
# 424.243_labels.csv
# 175.268_labels.csv
# 203.285_labels.csv
# 245.289_labels.csv
# 249.287_labels.csv
# 243.292_labels.csv
# 261.266_labels.csv
# 175.271_labels.csv
# 253.263_labels.csv
# 349.267_labels.csv
# 266.298_labels.csv
# 380.255_labels.csv
# 245.284_labels.csv
# 253.286_labels.csv
# 264.267_labels.csv
# 259.286_labels.csv
# 226.273_labels.csv
# 267.284_labels.csv
# 204.257_labels.csv
# 262.285_labels.csv
# 201.287_labels.csv
# 258.285_labels.csv
# 328.262_labels.csv
# 222.247_labels.csv
# 186.253_labels.csv
# 379.259_labels.csv
# 232.294_labels.csv
# 276.255_labels.csv
# 159.283_labels.csv
# 235.292_labels.csv
# 196.271_labels.csv
# 294.238_labels.csv
# 260.251_labels.csv
# 229.296_labels.csv
# 358.243_labels.csv
# 245.297_labels.csv
# 370.266_labels.csv
# 204.269_labels.csv
# 262.284_labels.csv
# 273.273_labels.csv
# 261.285_labels.csv
# 217.257_labels.csv
# 233.295_labels.csv
# 199.255_labels.csv
# 243.290_labels.csv
# 068.321_labels.csv
# 297.255_labels.csv
# 319.290_labels.csv
# 245.290_labels.csv
# 239.258_labels.csv
# 336.239_labels.csv
# 268.254_labels.csv
# 375.252_labels.csv
# 167.274_labels.csv
# 244.294_labels.csv
# 337.271_labels.csv
# 272.256_labels.csv
# 403.257_labels.csv
# 212.301_labels.csv
# 166.281_labels.csv
# 333.268_labels.csv
# 213.274_labels.csv
# 351.245_labels.csv
# 183.292_labels.csv
# 378.272_labels.csv
# 244.284_labels.csv
# 347.271_labels.csv
# 247.291_labels.csv
# 300.251_labels.csv
# 240.258_labels.csv
# 168.268_labels.csv
# 229.294_labels.csv
# 154.286_labels.csv
# 147.282_labels.csv
# 156.285_labels.csv
# 164.278_labels.csv
# 342.243_labels.csv
# 195.307_labels.csv
# 196.287_labels.csv
# 374.267_labels.csv
# 267.283_labels.csv
# 299.246_labels.csv
# 205.269_labels.csv
# 330.260_labels.csv
# 292.256_labels.csv
# 263.299_labels.csv
# 051.245_labels.csv
# 231.274_labels.csv
# 154.285_labels.csv
# 214.269_labels.csv
# 256.287_labels.csv
# 264.284_labels.csv
# 352.268_labels.csv
# 406.250_labels.csv
# 240.293_labels.csv
# 272.283_labels.csv
# 232.295_labels.csv
# 194.305_labels.csv
# 238.294_labels.csv
# 195.250_labels.csv
# 230.265_labels.csv
# 236.294_labels.csv
# 275.272_labels.csv
# 277.286_labels.csv
# 163.275_labels.csv
# 242.290_labels.csv
# 231.289_labels.csv
# 179.259_labels.csv
# 296.253_labels.csv
# 230.261_labels.csv
# 355.250_labels.csv
# 244.275_labels.csv
# 216.250_labels.csv
# 386.248_labels.csv
# 219.264_labels.csv
# 257.285_labels.csv
# 238.278_labels.csv
# 227.295_labels.csv
# 230.294_labels.csv
# 263.267_labels.csv
# 237.291_labels.csv
# 393.245_labels.csv
# 193.247_labels.csv
# 342.271_labels.csv
# 244.296_labels.csv
# 392.250_labels.csv
# 197.287_labels.csv
# 452.239_labels.csv
# labels/stronglensdb_confirmed_unige/CFIS u/
# 197.271_labels.csv
# 248.272_labels.csv
# 203.263_labels.csv
# 165.270_labels.csv
# 314.228_labels.csv
# 640.188_labels.csv
# 050.212_labels.csv
# 206.264_labels.csv
# 228.262_labels.csv
# 324.225_labels.csv
# 009.213_labels.csv
# 358.225_labels.csv
# 248.235_labels.csv
# 661.184_labels.csv
# 340.274_labels.csv
# 346.224_labels.csv
# 222.232_labels.csv
# 361.249_labels.csv
# 367.182_labels.csv
# 403.238_labels.csv
# 683.198_labels.csv
# 164.282_labels.csv
# 264.299_labels.csv
# 290.235_labels.csv
# 690.181_labels.csv
# 356.257_labels.csv
# 442.244_labels.csv
# 669.179_labels.csv
# 211.252_labels.csv
# 407.242_labels.csv
# 162.275_labels.csv
# 337.219_labels.csv
# 382.241_labels.csv
# 417.236_labels.csv
# 424.243_labels.csv
# 662.188_labels.csv
# 036.186_labels.csv
# 175.268_labels.csv
# 209.235_labels.csv
# 203.285_labels.csv
# 328.225_labels.csv
# 335.252_labels.csv
# 667.180_labels.csv
# 261.266_labels.csv
# 398.226_labels.csv
# 175.271_labels.csv
# 253.263_labels.csv
# 259.300_labels.csv
# 327.231_labels.csv
# 670.209_labels.csv
# 033.184_labels.csv
# 266.298_labels.csv
# 295.237_labels.csv
# 022.182_labels.csv
# 380.255_labels.csv
# 679.187_labels.csv
# 374.225_labels.csv
# 226.273_labels.csv
# 204.257_labels.csv
# 201.287_labels.csv
# 057.252_labels.csv
# 346.246_labels.csv
# 328.262_labels.csv
# 210.230_labels.csv
# 222.247_labels.csv
# 692.181_labels.csv
# 356.182_labels.csv
# 193.245_labels.csv
# 186.253_labels.csv
# 714.180_labels.csv
# 339.247_labels.csv
# 381.245_labels.csv
# 282.233_labels.csv
# 379.259_labels.csv
# 276.255_labels.csv
# 223.231_labels.csv
# 196.271_labels.csv
# 294.238_labels.csv
# 260.251_labels.csv
# 447.223_labels.csv
# 326.253_labels.csv
# 238.217_labels.csv
# 358.243_labels.csv
# 370.266_labels.csv
# 204.269_labels.csv
# 661.219_labels.csv
# 469.218_labels.csv
# 671.183_labels.csv
# 217.257_labels.csv
# 199.255_labels.csv
# 386.247_labels.csv
# 297.255_labels.csv
# 319.290_labels.csv
# 239.258_labels.csv
# 336.239_labels.csv
# 086.181_labels.csv
# 651.180_labels.csv
# 268.254_labels.csv
# 018.198_labels.csv
# 375.252_labels.csv
# 167.274_labels.csv
# 337.271_labels.csv
# 034.210_labels.csv
# 448.216_labels.csv
# 272.256_labels.csv
# 403.257_labels.csv
# 641.188_labels.csv
# 166.281_labels.csv
# 333.268_labels.csv
# 553.254_labels.csv
# 229.220_labels.csv
# 351.245_labels.csv
# 183.292_labels.csv
# 378.272_labels.csv
# 347.271_labels.csv
# 349.186_labels.csv
# 300.251_labels.csv
# 240.258_labels.csv
# 168.268_labels.csv
# 252.220_labels.csv
# 224.234_labels.csv
# 147.282_labels.csv
# 345.236_labels.csv
# 164.278_labels.csv
# 342.243_labels.csv
# 196.287_labels.csv
# 013.231_labels.csv
# 014.193_labels.csv
# 033.183_labels.csv
# 374.267_labels.csv
# 299.246_labels.csv
# 205.269_labels.csv
# 330.260_labels.csv
# 292.256_labels.csv
# 373.180_labels.csv
# 263.299_labels.csv
# 051.245_labels.csv
# 231.274_labels.csv
# 214.269_labels.csv
# 711.180_labels.csv
# 329.253_labels.csv
# 352.268_labels.csv
# 352.253_labels.csv
# 406.250_labels.csv
# 369.220_labels.csv
# 472.227_labels.csv
# 372.247_labels.csv
# 265.233_labels.csv
# 662.184_labels.csv
# 195.250_labels.csv
# 296.236_labels.csv
# 644.204_labels.csv
# 698.191_labels.csv
# 230.265_labels.csv
# 326.219_labels.csv
# 659.204_labels.csv
# 163.275_labels.csv
# 013.214_labels.csv
# 179.259_labels.csv
# 296.253_labels.csv
# 004.180_labels.csv
# 464.230_labels.csv
# 230.261_labels.csv
# 450.233_labels.csv
# 355.250_labels.csv
# 375.243_labels.csv
# 327.218_labels.csv
# 244.275_labels.csv
# 216.250_labels.csv
# 386.248_labels.csv
# 219.264_labels.csv
# 353.180_labels.csv
# 238.278_labels.csv
# 359.250_labels.csv
# 712.179_labels.csv
# 033.219_labels.csv
# 056.182_labels.csv
# 348.187_labels.csv
# 393.245_labels.csv
# 193.247_labels.csv
# 667.182_labels.csv
# 342.271_labels.csv
# 395.228_labels.csv
# 360.180_labels.csv
# 638.185_labels.csv
# 392.250_labels.csv
# 197.287_labels.csv
# 667.179_labels.csv
# 042.188_labels.csv
# 659.188_labels.csv
# 452.239_labels.csv

# %%
broken_tiles = []
prev_conf = {'197.271': None} #dictionary of previously seen tiles
cutout_size = 64
for label_subdir in [label_subdirs[0]]:
    for f in [filters[0],filters[2]]:
        subdir = label_dir + label_subdir + f
        print(subdir)
        z=0
        for csv in ['297.255_labels.csv']:
            if z < 2:
                z+=1
                tile_id = csv[:7] # XXX.XXX id
                print('id', tile_id)
    #                 img_group_name = label_subdir + tile_id + "/" + f + "IMAGES"
    #                 wt_group_name = label_subdir + tile_id + "/" + f + "WEIGHTS"

                img_group_name =  tile_id + "/" + "IMAGES"
                wt_group_name  =  tile_id + "/" + "WEIGHTS"
                tile_name = f.split(" ")[0] + "." + tile_id + "." + f.split(" ")[1][0]
               
                #FILES
                #weight
                if "CFIS" in f:
                    wt_name = ".weight.fits.fz"
                    wt_index = 1
                else:
                    wt_name = ".wt.fits"
                    wt_index = 0
                
                #files
                img_fits = fits.open(image_dir + tile_name + ".fits", memmap=True)
                wt_fits  = fits.open(image_dir + tile_name + wt_name, memmap=True)
                cat = table.Table.read(image_dir + tile_name + '.cat', format="ascii.sextractor")

                new_group = False
                if img_group_name not in hf:
                    new_group = True
                    img_group = hf.create_group(img_group_name)
                    wt_group = hf.create_group(wt_group_name)

                    img_cutout_all = np.random.normal(loc = 0.5,scale= 0.13, size=(cutout_size, cutout_size,5))
                    #img_cutout = np.zeros((cutout_size, cutout_size, 5)) 
                    wt_cutout_all  = np.zeros((cutout_size, cutout_size, 5))

                    #generate list of random cutouts
                    rand_cutouts = random.sample(range(len(cat)),2)

                else:
                    img_group = hf[img_group_name]
                    wt_group = hf[wt_group_name]

                    #want the same cutouts as previous, with previous catalogue (u)
                    list_cutouts = list(hf[img_group_name].keys())
                    #prev random cutouts
                    rand_cutouts = [int((i[1:]).split("-")[0]) for i in list_cutouts if  'u' not in (i[1:]).split("-")] 
                    #prev confirmed cutouts
                    cat_prev = table.Table.read(image_dir + tile_name[:-1] + 'u' + '.cat', format="ascii.sextractor")


                #### make cutouts
                count = 0 
                #candidates cutouts
                df = pd.read_csv(subdir + csv)
                nlabels = len(df)
                
            #----create candidate cutout from previous catalogue----#    
                if (tile_id + '-0') in prev_conf:
                    j = 0 
                    try_tile = tile_id + '-0' #first cutout is labelled with 0 for sure
                    if try_tile in prev_conf:
                        (x,y) =prev_conf[tile_id + '-' + str(count)] 
                        try:
                            (img_cutout, wt_cutout) = create_cutouts(img_fits[0], wt_fits[wt_index], x, y, tile_name[-1])
                        except:
                            broken_tiles.append(tile_name) 
                            pass
                        
                        count += 1
                        j+=1
                        try_tile = tile_id + f'-{j}'
#                         print('previous done')
                    else:
#                         print('all u cutouts done in r')
                         break
                    
#                     print('onto new confirmed r cutouts')
                    
            #----create candidate cutout from current catalogue----#    
                count = 0
                for n in range(nlabels): 
                    x = df["x"][n]
                    y = df["y"][n]
                    #save x,y for u channel
                    if tile_name[-1] == 'u':
                        prev_conf[tile_id + '-' + str(count)] = (x,y)
                    #make cutout
                    try:
                        (img_cutout, wt_cutout) = create_cutouts(img_fits[0], wt_fits[wt_index], x, y, tile_name[-1])
                    except:
                        broken_tiles.append(tile_name) 
                        pass

                    print('should be 0', count)
                    count += 1
                    
                    print('new cand')
                    img_cutout_all[:,:,filter_dict[f]] = img_cutout
                    wt_cutout_all[:,:,filter_dict[f]]  = wt_cutout

                    img_group.create_dataset(f"c{n}-"+tile_name[-1], data=img_cutout_all)
                    wt_group.create_dataset(f"c{n}-"+tile_name[-1], data=wt_cutout_all)
                       
                print(f'done {count}')
                
            #----create extra random cutout from current catalogue----#   
                for n in rand_cutouts:
                    #if cat["FLAGS"][n] != 0 or cat["MAG_AUTO"][n] >= 99.0 or cat["MAGERR_AUTO"][n] <= 0 or cat["MAGERR_AUTO"][n] >= 1:
                    #    continue
                
                    count += 1
                    if new_group is True: #create cutout from current catalogue if new group
                        x = cat["X_IMAGE"][n]
                        y = cat["Y_IMAGE"][n]
                        try:
                            (img_cutout, wt_cutout) = create_cutouts(img_fits[0], wt_fits[wt_index], x, y, f[-2])
                        except:
                            broken_tiles.append(tile_name) 
                            pass

                        img_cutout_all[:,:,filter_dict[f]] = img_cutout
                        wt_cutout_all[:,:,filter_dict[f]]  = wt_cutout
                        
                        img_group.create_dataset(f"c{n}", data=img_cutout_all)
                        wt_group.create_dataset(f"c{n}", data=wt_cutout_all)
                    
                    else:                 #add cutout to existing group
                        x = cat_prev["X_IMAGE"][n]
                        y = cat_prev["Y_IMAGE"][n]
                        try:
                            (img_cutout, wt_cutout) = create_cutouts(img_fits[0], wt_fits[wt_index], x, y, f[-2])
                        except:
                            broken_tiles.append(tile_name) 
                            pass

                        if img_cutout is None:
                            img_cutout = np.random.normal(loc = 0.5,scale= 0.13, size=(cutout_size, cutout_size))
                            wt_cutout  = np.zeros((cutout_size, cutout_size))
                        else:
                            hf[img_group_name + f"/c{n}"][...,filter_dict[f]] = img_cutout
                            hf[wt_group_name + f"/c{n}"][...,filter_dict[f]] = wt_cutout

                    print(len(rand_cutouts),n, count)
                print(f'done {count}')
       
                img_fits.close()
                wt_fits.close()
        print(f"Finished {label_subdir}")
# Out:
# labels/stronglensdb_confirmed_unige/CFIS u/
# id 297.255
# should be 0 0
# new cand
# done 1
# 2 10131 2
# 2 5747 3
# done 3
# Finished stronglensdb_confirmed_unige/
# labels/stronglensdb_confirmed_unige/CFIS r/
# id 297.255
# should be 0 0
# new cand
# done 1
# 2 10131 2
# 2 5747 3
# done 3
# Finished stronglensdb_confirmed_unige/

# %%
broken_tiles
np.savetxt("broken_tiles.csv", broken_tiles, delimiter =", ", fmt ='% s')

# %%
hf['297.255/WEIGHTS'].keys()
# Out:
# <KeysViewHDF5 ['c0-r', 'c0-u', 'c2259', 'c6945']>

# %%
plt.imshow(np.array(hf['297.255/IMAGES/c6945'])[...,2])

# %% [markdown]
# ---
# # Testing

# %%
img_cutout

# %%
plt.imshow(img_cutout.shape
# Out:
# (64, 64)

# %%
hf.keys()
# Out:
# <KeysViewHDF5 ['050.212', '147.288', '165.270', '197.271', '201.311', '203.263', '204.278', '206.264', '228.262', '234.295', '241.290', '248.272', '260.284', '314.228', '324.225', '640.188']>

# %%
hf['165.270/IMAGES'].keys()
# Out:
# <KeysViewHDF5 ['c0-r', 'c0-u', 'c1861', 'c2418']>

# %%
tile = '165.270'
cut  = 'c2644'
r_band_only = np.array(hf['165.270/IMAGES/c0-r'])
u_band_only = np.array(hf['165.270/IMAGES/c0-u'])
tile        = np.array(hf['165.270/IMAGES/c1861'])

weight = np.array(hf['165.270/WEIGHTS/c1861'])
r_w    = np.array(hf['165.270//WEIGHTS/c0-r'])
u_w    = np.array(hf['165.270//WEIGHTS/c0-u'])

# %%
fig, axes = plt.subplots(5, 6)
for i in range(5):
    axes[i][0].imshow(r_band_only[...,i])
    axes[i][1].imshow(u_band_only[...,i])
    axes[i][2].imshow(tile[...,i])
    axes[i][3].imshow(r_w[...,i])
    axes[i][4].imshow(u_w[...,i])
    axes[i][5].imshow(weight[...,i])

# %%
hf.close()
src = os.path.expandvars("$SLURM_TMPDIR") + "/labelled_cutouts_64p.h5"
dest = os.path.expandvars("$SCRATCH") + "/"
shutil.copy2(src, dest)
# Out:
# '/scratch/anahoban/labelled_cutouts_64p.h5'

# %%
hf.close()

# %%
tile_ids = list(hf.keys())

# %%
n_cutouts = 0
for i in range(len(tile_ids)):
    n = len(hf.get(tile_ids[i] + "/IMAGES"))
    n_cutouts += n
print(n_cutouts)
# Out:
# 103981
